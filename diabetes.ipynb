# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import classification_report, confusion_matrix, roc_auc_score

# %%
data = pd.read_csv("diabetes_dataset.csv")
df = pd.DataFrame(data)

# %%
df = df.drop(["Unnamed: 0", "Ethnicity"], axis=1)

# %%
df
# Out:
#       Age     Sex   BMI  Waist_Circumference  Fasting_Blood_Glucose  HbA1c  \
# 0      58  Female  35.8                 83.4                  123.9   10.9
# 1      48    Male  24.1                 71.4                  183.7   12.8
# 2      34  Female  25.0                113.8                  142.0   14.5
# 3      62    Male  32.7                100.4                  167.4    8.8
# 4      27  Female  33.5                110.8                  146.4    7.1
# ...   ...     ...   ...                  ...                    ...    ...
# 9995   45  Female  39.4                114.0                   76.2   13.4
# 9996   41  Female  21.0                 71.3                   77.1   12.9
# 9997   50  Female  29.0                106.3                   97.5    4.9
# 9998   62  Female  27.3                119.9                   89.0   11.5
# 9999   29    Male  20.6                102.0                   70.8   14.5
#
#       Blood_Pressure_Systolic  Blood_Pressure_Diastolic  Cholesterol_Total  \
# 0                         152                       114              197.8
# 1                         103                        91              261.6
# 2                         179                       104              261.0
# 3                         176                       118              183.4
# 4                         122                        97              203.2
# ...                       ...                       ...                ...
# 9995                      109                        82              187.7
# 9996                      154                        72              234.3
# 9997                      122                        61              266.0
# 9998                       99                       115              172.3
# 9999                      156                        64              277.9
#
#       Cholesterol_HDL  Cholesterol_LDL   GGT  Serum_Urate  \
# 0                50.2             99.2  37.5          7.2
# 1                62.0            146.4  88.5          6.1
# 2                32.1            164.1  56.2          6.9
# 3                41.1             84.0  34.4          5.4
# 4                53.9             92.8  81.9          7.4
# ...               ...              ...   ...          ...
# 9995             60.3             88.7  19.1          6.1
# 9996             72.3            200.0  37.1          3.5
# 9997             69.8            156.1  85.8          4.9
# 9998             74.2            110.9  25.3          5.2
# 9999             38.0            108.1  68.5          6.0
#
#      Physical_Activity_Level  Dietary_Intake_Calories Alcohol_Consumption  \
# 0                   Moderate                     1538            Moderate
# 1                   Moderate                     2653            Moderate
# 2                        Low                     1684               Heavy
# 3                        Low                     3796            Moderate
# 4                   Moderate                     3161               Heavy
# ...                      ...                      ...                 ...
# 9995                     Low                     3582                 NaN
# 9996                     Low                     2206                 NaN
# 9997                    High                     3175               Heavy
# 9998                    High                     3478            Moderate
# 9999                     Low                     2918               Heavy
#
#      Smoking_Status  Family_History_of_Diabetes  Previous_Gestational_Diabetes
# 0             Never                           0                              1
# 1           Current                           0                              1
# 2            Former                           1                              0
# 3             Never                           1                              0
# 4           Current                           0                              0
# ...             ...                         ...                            ...
# 9995         Former                           1                              1
# 9996          Never                           1                              1
# 9997         Former                           1                              1
# 9998          Never                           1                              0
# 9999         Former                           1                              0
#
# [10000 rows x 19 columns]

# %%
risk_conditions = (
    (df['HbA1c'] >= 6.5).astype(int) +
    (df['Fasting_Blood_Glucose'] >= 126).astype(int) +
    (df['BMI'] >= 30).astype(int) +
    (df['Waist_Circumference'] >= 100).astype(int) +
    (df['Blood_Pressure_Systolic'] >= 130).astype(int) +
    (df['Blood_Pressure_Diastolic'] >= 85).astype(int) +
    ((df['Sex'] == 'Female') & (df['Previous_Gestational_Diabetes'] == 1)).astype(int)
)

df['Diabetic'] = (risk_conditions >= 4).astype(int)

# %%
missing_percentage = df['Alcohol_Consumption'].isnull().mean() * 100
print(f"Missing: {missing_percentage:.2f}%")
# Out:
# Missing: 33.20%

# %%
df['Alcohol_Consumption'] = df['Alcohol_Consumption'].fillna('Unknown')

# %%
X = df.drop(columns=['Diabetic'])
y = df['Diabetic']

# %%
print(X)
# Out:
#       Age     Sex   BMI  Waist_Circumference  Fasting_Blood_Glucose  HbA1c  \
# 0      58  Female  35.8                 83.4                  123.9   10.9
# 1      48    Male  24.1                 71.4                  183.7   12.8
# 2      34  Female  25.0                113.8                  142.0   14.5
# 3      62    Male  32.7                100.4                  167.4    8.8
# 4      27  Female  33.5                110.8                  146.4    7.1
# ...   ...     ...   ...                  ...                    ...    ...
# 9995   45  Female  39.4                114.0                   76.2   13.4
# 9996   41  Female  21.0                 71.3                   77.1   12.9
# 9997   50  Female  29.0                106.3                   97.5    4.9
# 9998   62  Female  27.3                119.9                   89.0   11.5
# 9999   29    Male  20.6                102.0                   70.8   14.5
#
#       Blood_Pressure_Systolic  Blood_Pressure_Diastolic  Cholesterol_Total  \
# 0                         152                       114              197.8
# 1                         103                        91              261.6
# 2                         179                       104              261.0
# 3                         176                       118              183.4
# 4                         122                        97              203.2
# ...                       ...                       ...                ...
# 9995                      109                        82              187.7
# 9996                      154                        72              234.3
# 9997                      122                        61              266.0
# 9998                       99                       115              172.3
# 9999                      156                        64              277.9
#
#       Cholesterol_HDL  Cholesterol_LDL   GGT  Serum_Urate  \
# 0                50.2             99.2  37.5          7.2
# 1                62.0            146.4  88.5          6.1
# 2                32.1            164.1  56.2          6.9
# 3                41.1             84.0  34.4          5.4
# 4                53.9             92.8  81.9          7.4
# ...               ...              ...   ...          ...
# 9995             60.3             88.7  19.1          6.1
# 9996             72.3            200.0  37.1          3.5
# 9997             69.8            156.1  85.8          4.9
# 9998             74.2            110.9  25.3          5.2
# 9999             38.0            108.1  68.5          6.0
#
#      Physical_Activity_Level  Dietary_Intake_Calories Alcohol_Consumption  \
# 0                   Moderate                     1538            Moderate
# 1                   Moderate                     2653            Moderate
# 2                        Low                     1684               Heavy
# 3                        Low                     3796            Moderate
# 4                   Moderate                     3161               Heavy
# ...                      ...                      ...                 ...
# 9995                     Low                     3582             Unknown
# 9996                     Low                     2206             Unknown
# 9997                    High                     3175               Heavy
# 9998                    High                     3478            Moderate
# 9999                     Low                     2918               Heavy
#
#      Smoking_Status  Family_History_of_Diabetes  Previous_Gestational_Diabetes
# 0             Never                           0                              1
# 1           Current                           0                              1
# 2            Former                           1                              0
# 3             Never                           1                              0
# 4           Current                           0                              0
# ...             ...                         ...                            ...
# 9995         Former                           1                              1
# 9996          Never                           1                              1
# 9997         Former                           1                              1
# 9998          Never                           1                              0
# 9999         Former                           1                              0
#
# [10000 rows x 19 columns]

# %%
X = pd.get_dummies(X, drop_first=True)

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.4, stratify=y, random_state=42)

# %%
model = RandomForestClassifier(n_estimators=100, random_state=42)
model.fit(X_train, y_train)
# Out:
# RandomForestClassifier(random_state=42)

# %%
y_pred = model.predict(X_test)
y_prob = model.predict_proba(X_test)[:, 1]

# %%
print("Confusion Matrix:")
print(confusion_matrix(y_test, y_pred))

print("Classification Report:")
print(classification_report(y_test, y_pred))

print(f"ROC AUC Score: {roc_auc_score(y_test, y_prob):.4f}")
# Out:
# Confusion Matrix:
# [[1812   10]
#  [  52 2126]]
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.97      0.99      0.98      1822
#            1       1.00      0.98      0.99      2178
#
#     accuracy                           0.98      4000
#    macro avg       0.98      0.99      0.98      4000
# weighted avg       0.98      0.98      0.98      4000
#
# ROC AUC Score: 0.9993
